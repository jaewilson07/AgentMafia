# %%
#| default_exp routes.crawler

# %% [markdown]
# # Crawl4AI Routes
# > Default description (change me)
#
# ## Post Installation
#
# Run post-installation setup
# in terminal make sure to run
#
# ```terminal
# crawl4ai-setup
# ```
#
# Followed by Verifying your installation
#
# ```terminal
# crawl4ai-doctor
# ```

# %%
#| export
from crawl4ai import AsyncWebCrawler, BrowserConfig, CrawlerRunConfig, CacheMode

from agent_mafia.client.ResponseGetData import ResponseGetDataCrawler

# %%
#| exporti
from typing import Callable
from agent_mafia.client import MafiaError as amme

# %%
#| hide
import nbdev
from functools import partial
from agent_mafia.routes.storage import save_chunk_to_disk

# %%
#| export
default_browser_config = BrowserConfig(
    browser_type="chromium",
    headless=True,
    verbose=True,
    extra_args=["--disable-gpu", "--disable-dev-shm-usage", "--no-sandbox"],
)

# %%
#| export
class Crawler_Route_NotSuccess(amme.MafiaError):
    def __init__(self, message, exception = None):
        super().__init__(message = message, exception = exception)

# %%
#| export
async def scrape_url(
    url: str,
    session_id: str,
    browser_config: BrowserConfig = None,
    storage_fn: Callable = None,
):

    browser_config = browser_config or default_browser_config

    res = None
    content = None

    try:
        async with AsyncWebCrawler(config=browser_config) as crawler:
            crawl_config = CrawlerRunConfig(cache_mode=CacheMode.BYPASS)

            res = await crawler.arun(
                url=url,
                config=crawl_config,
                session_id=session_id,
                timeout=15,
            )


    except NotImplementedError as e:
        raise Crawler_Route_NotSuccess(message = "have you run create4ai-create and create4ai-doctor? in terminal", exception = e)

    if not res.success:
        raise Crawler_Route_NotSuccess(message = f"error crawling {url} - {res.error_message}")
    
    rgd = ResponseGetDataCrawler.from_res(res)

    if storage_fn:
        storage_fn(
            data = {
                'content' : res.markdown,
                'source' : session_id,
                'url' : url,})

    return rgd

# %%
res = await scrape_url(
    url = 'https://docs.tavily.com/sdk/python/quick-start',
    session_id = 'tavily_docs',
    browser_config = default_browser_config,
    storage_fn = partial(save_chunk_to_disk, output_path = '../../TEST/crawler_routes/scrape_tavily.md')
)
res
# Out:
# [INIT].... → Crawl4AI 0.5.0.post4

# %%
from pprint import pprint

pprint(res[0].__dict__)
# Out:
# {'cleaned_html': '<div><main><div><div><div><div><div><div><div><div><a '
#                  'href="https://tavily.com/"><span>Tavily Docs home '
#                  'page</span><img alt="light logo" class="w-auto h-7 relative '
#                  'object-contain block dark:hidden" '
#                  'src="https://mintlify.s3.us-west-1.amazonaws.com/tavilyai/logo/light.svg"/><img '
#                  'alt="dark logo" class="w-auto h-7 relative object-contain '
#                  'hidden dark:block" '
#                  'src="https://mintlify.s3.us-west-1.amazonaws.com/tavilyai/logo/dark.svg"/></a></div><button><div><div>Search '
#                  'or ask...</div></div><span>Ctrl '
#                  'K</span></button><div><nav><ul><li><a '
#                  'href="mailto:support@tavily.com">Support</a></li><li><a '
#                  'href="https://app.tavily.com">Get an API key</a></li><li><a '
#                  'href="https://app.tavily.com"><div><span>Get an API '
#                  'key</span></div></a></li></ul></nav></div><div><button><span>Search...</span></button></div></div></div><div><button><span>Navigation</span></button><div><div><span>Python</span></div><div>Quickstart</div></div></div></div><div><div><a '
#                  'href="/welcome">Home</a><a '
#                  'href="/documentation/about">Documentation</a><a '
#                  'href="/sdk/python/quick-start">SDKs</a><a '
#                  'href="/examples/use-cases/data-enrichment">Examples</a></div></div></div></div></div><div><div><div><div><div><li><a '
#                  'href="https://app.tavily.com/playground">API '
#                  'Playground</a></li><li><a '
#                  'href="https://community.tavily.com">Community</a></li><li><a '
#                  'href="https://blog.tavily.com">Blog</a></li><div><h5>Python</h5><ul><li><a '
#                  'href="/sdk/python/quick-start"><div><div>Quickstart</div></div></a></li><li><a '
#                  'href="/sdk/python/reference"><div><div>SDK '
#                  'Reference</div></div></a></li></ul></div><div><h5>JavaScript</h5><ul><li><a '
#                  'href="/sdk/javascript/quick-start"><div><div>Quickstart</div></div></a></li><li><a '
#                  'href="/sdk/javascript/reference"><div><div>SDK '
#                  'Reference</div></div></a></li></ul></div></div></div></div></div><div><div><div><header><div><div>Python</div><div><h1>Quickstart</h1></div></div><div><p>Integrate '
#                  'Tavily’s powerful APIs natively in your Python '
#                  'apps.</p></div></header><div><div><div><p>Looking for the '
#                  'Python SDK Reference? Head to our <a '
#                  'href="/sdk/python/reference">Python SDK Reference</a> and '
#                  'learn how to use '
#                  '<code>tavily-python</code>.</p></div></div>\n'
#                  '<h2><div><a '
#                  'href="#introduction">\u200b</a></div><span>Introduction</span></h2>\n'
#                  '<p>The Python SDK allows for easy interaction with the '
#                  'Tavily API, offering the full range of our search '
#                  'functionality directly from your Python programs. Easily '
#                  'integrate smart search capabilities into your applications, '
#                  'harnessing Tavily’s powerful search features.</p>\n'
#                  '<div><a '
#                  'href="https://github.com/tavily-ai/tavily-python"><div><div><h2>GitHub</h2><div><p><code>/tavily-ai/tavily-python</code></p><img '
#                  'alt="GitHub Repo stars" '
#                  'src="https://img.shields.io/github/stars/tavily-ai/tavily-python?style=social"/></div></div></div></a><a '
#                  'href="https://pypi.org/project/tavily-python"><div><div><h2>PyPI</h2><div><p><code>tavily-python</code></p><img '
#                  'alt="PyPI downloads" height="20" '
#                  'src="https://img.shields.io/pypi/dm/tavily-python" '
#                  'width="148"/></div></div></div></a></div>\n'
#                  '<h2><div><a '
#                  'href="#quickstart">\u200b</a></div><span>Quickstart</span></h2>\n'
#                  '<p>Get started with our Python SDK in less than 5 '
#                  'minutes!</p>\n'
#                  '<a href="https://app.tavily.com"><div><div><h2>Get your free '
#                  'API key</h2><div><p>You get 1,000 free API Credits every '
#                  'month. <strong>No credit card '
#                  'required.</strong></p></div></div></div></a>\n'
#                  '<h3><div><a '
#                  'href="#installation">\u200b</a></div><span>Installation</span></h3>\n'
#                  '<p>You can install the Tavily Python SDK using the '
#                  'following:</p>\n'
#                  '<div><div><div>Copy</div></div><div><div><pre><code><span>pip '
#                  '<span>install</span> tavily-python</span>\n'
#                  '</code></pre></div></div></div>\n'
#                  '<h3><div><a '
#                  'href="#usage">\u200b</a></div><span>Usage</span></h3>\n'
#                  '<p>With Tavily’s Python SDK, you can search the web in only '
#                  '4 lines of code:</p>\n'
#                  '<div><div><div>Copy</div></div><div><div><pre><code><span><span>from</span> '
#                  'tavily <span>import</span> TavilyClient</span>\n'
#                  '<span>tavily_client <span>=</span> '
#                  'TavilyClient<span>(</span>api_key<span>=</span><span>"tvly-YOUR_API_KEY"</span><span>)</span></span>\n'
#                  '<span>response <span>=</span> '
#                  'tavily_client<span>.</span>search<span>(</span><span>"Who is '
#                  'Leo Messi?"</span><span>)</span></span>\n'
#                  '<span><span>print</span><span>(</span>response<span>)</span></span>\n'
#                  '</code></pre></div></div></div>\n'
#                  '<p>You can also easily extract content from URLs:</p>\n'
#                  '<div><div><div>Copy</div></div><div><div><pre><code><span><span>from</span> '
#                  'tavily <span>import</span> TavilyClient</span>\n'
#                  '<span>tavily_client <span>=</span> '
#                  'TavilyClient<span>(</span>api_key<span>=</span><span>"tvly-YOUR_API_KEY"</span><span>)</span></span>\n'
#                  '<span>response <span>=</span> '
#                  'tavily_client<span>.</span>extract<span>(</span><span>"https://en.wikipedia.org/wiki/Lionel_Messi"</span><span>)</span></span>\n'
#                  '<span><span>print</span><span>(</span>response<span>)</span></span>\n'
#                  '</code></pre></div></div></div>\n'
#                  '<p>These examples are very simple, and you can do so much '
#                  'more with Tavily!</p>\n'
#                  '<h2><div><a '
#                  'href="#features">\u200b</a></div><span>Features</span></h2>\n'
#                  '<p>Our Python SDK supports the full feature range of our <a '
#                  'href="/api-reference">REST API</a>, and more. We offer both '
#                  'a synchronous and an asynchronous client, for increased '
#                  'flexibility.</p>\n'
#                  '<ul>\n'
#                  '<li>The <code>search</code> function lets you harness the '
#                  'full power of Tavily Search.</li>\n'
#                  '<li>The <code>extract</code> function allows you to easily '
#                  'retrieve web content with Tavily Extract.</li>\n'
#                  '</ul>\n'
#                  '<p>For more details, head to the <a '
#                  'href="/sdk/python/reference">Python SDK '
#                  'Reference</a>.</p></div><div><div><a '
#                  'href="/sdk/python/reference"><span>SDK '
#                  'Reference</span></a></div><footer><div><a '
#                  'href="https://x.com/tavilyai"><span>x</span></a><a '
#                  'href="https://github.com/tavily-ai"><span>github</span></a><a '
#                  'href="https://linkedin.com/company/tavily"><span>linkedin</span></a><a '
#                  'href="https://tavily.com"><span>website</span></a></div><div><div><a '
#                  'href="https://mintlify.com/preview-request?utm_campaign=poweredBy&amp;utm_medium=docs&amp;utm_source=docs.tavily.com">Powered '
#                  'by '
#                  'Mintlify</a></div></div></footer></div></div><div><div><div><div><span>On '
#                  'this page</span></div><ul><li><a '
#                  'href="#introduction">Introduction</a></li><li><a '
#                  'href="#quickstart">Quickstart</a></li><li><a '
#                  'href="#installation">Installation</a></li><li><a '
#                  'href="#usage">Usage</a></li><li><a '
#                  'href="#features">Features</a></li></ul></div></div></div></div></div></div></div></main></div>',
#  'dispatch_result': None,
#  'downloaded_files': None,
#  'error_message': '',
#  'extracted_content': None,
#  'html': '<!DOCTYPE html><html lang="en" class="js-focus-visible '
#          'lg:[--scroll-mt:9.5rem]" data-js-focus-visible=""><head><meta '
#          'charset="utf-8"><meta name="viewport" '
#          'content="width=device-width"><link rel="apple-touch-icon" '
#          'type="image/png" sizes="180x180" '
#          'href="https://mintlify.s3-us-west-1.amazonaws.com/tavilyai/_generated/favicon/apple-touch-icon.png?v=3"><link '
#          'rel="icon" type="image/png" sizes="32x32" '
#          'href="https://mintlify.s3-us-west-1.amazonaws.com/tavilyai/_generated/favicon/favicon-32x32.png?v=3"><link '
#          'rel="icon" type="image/png" sizes="16x16" '
#          'href="https://mintlify.s3-us-west-1.amazonaws.com/tavilyai/_generated/favicon/favicon-16x16.png?v=3"><link '
#          'rel="shortcut icon" type="image/x-icon" '
#          'href="https://mintlify.s3-us-west-1.amazonaws.com/tavilyai/_generated/favicon/favicon.ico?v=3"><meta '
#          'name="msapplication-config" '
#          'content="https://mintlify.s3-us-west-1.amazonaws.com/tavilyai/_generated/favicon/browserconfig.xml?v=3"><meta '
#          'name="apple-mobile-web-app-title" content="Tavily Docs"><meta '
#          'name="application-name" content="Tavily Docs"><meta '
#          'name="msapplication-TileColor" content="#FDBB11"><meta '
#          'name="theme-color" content="#ffffff"><meta name="generator" '
#          'content="Mintlify"><link rel="sitemap" type="application/xml" '
#          'href="/sitemap.xml"><meta name="charset" content="utf-8"><meta '
#          'name="og:type" content="website"><meta name="og:site_name" '
#          'content="Tavily Docs"><meta name="twitter:card" '
#          'content="summary_large_image"><meta name="og:title" '
#          'content="Quickstart - Tavily Docs"><meta name="twitter:title" '
#          'content="Quickstart - Tavily Docs"><meta name="og:description" '
#          'content="Integrate Tavily\'s powerful APIs natively in your Python '
#          'apps."><meta name="description" content="Integrate Tavily\'s '
#          'powerful APIs natively in your Python apps."><meta '
#          'property="og:image" '
#          'content="https://tavilyai.mintlify.app/_next/image?url=%2Fapi%2Fog%3Fdivision%3DDocumentation%26title%3DQuickstart%26description%3DIntegrate%2BTavily%2527s%2Bpowerful%2BAPIs%2Bnatively%2Bin%2Byour%2BPython%2Bapps.%26logoLight%3Dhttps%253A%252F%252Fmintlify.s3.us-west-1.amazonaws.com%252Ftavilyai%252Flogo%252Flight.svg%26logoDark%3Dhttps%253A%252F%252Fmintlify.s3.us-west-1.amazonaws.com%252Ftavilyai%252Flogo%252Fdark.svg%26primaryColor%3D%2523FDBB11%26lightColor%3D%2523FDBB11%26darkColor%3D%2523468BFF&amp;w=1200&amp;q=100"><meta '
#          'property="og:image:width" content="1200"><meta '
#          'property="og:image:height" content="630"><meta '
#          'property="twitter:image" '
#          'content="https://tavilyai.mintlify.app/_next/image?url=%2Fapi%2Fog%3Fdivision%3DDocumentation%26title%3DQuickstart%26description%3DIntegrate%2BTavily%2527s%2Bpowerful%2BAPIs%2Bnatively%2Bin%2Byour%2BPython%2Bapps.%26logoLight%3Dhttps%253A%252F%252Fmintlify.s3.us-west-1.amazonaws.com%252Ftavilyai%252Flogo%252Flight.svg%26logoDark%3Dhttps%253A%252F%252Fmintlify.s3.us-west-1.amazonaws.com%252Ftavilyai%252Flogo%252Fdark.svg%26primaryColor%3D%2523FDBB11%26lightColor%3D%2523FDBB11%26darkColor%3D%2523468BFF&amp;w=1200&amp;q=100"><meta '
#          'property="twitter:image:width" content="1200"><meta '
#          'property="twitter:image:height" content="630"><title>Quickstart - '
#          'Tavily Docs</title><meta name="og:url" '
#          'content="https://docs.tavily.com/sdk/python/quick-start"><link '
#          'rel="canonical" '
#          'href="https://docs.tavily.com/sdk/python/quick-start"><meta '
#          'name="next-head-count" content="30"><link rel="stylesheet" '
#          'href="https://cdn.jsdelivr.net/npm/katex@0.16.0/dist/katex.min.css" '
#          'integrity="sha384-Xi8rHCmBmhbuyyhbI88391ZKP2dmfnOl4rT9ZfRI7mLTdk1wblIUnrIq35nqwEvC" '
#          'crossorigin="anonymous"><link rel="preload" '
#          'href="/_next/static/media/a34f9d1faa5f3315-s.p.woff2" as="font" '
#          'type="font/woff2" crossorigin="anonymous" '
#          'data-next-font="size-adjust"><link rel="preload" '
#          'href="/_next/static/media/bb3ef058b751a6ad-s.p.woff2" as="font" '
#          'type="font/woff2" crossorigin="anonymous" '
#          'data-next-font="size-adjust"><script id="mode-toggle" '
#          'data-nscript="beforeInteractive">\n'
#          '      try {\n'
#          "        if (localStorage.isDarkMode === 'true') {\n"
#          "          document.documentElement.classList.add('dark');\n"
#          "        } else if (localStorage.isDarkMode === 'false') {\n"
#          "          document.documentElement.classList.remove('dark');\n"
#          "        } else if ((true && !('isDarkMode' in localStorage) && "
#          "window.matchMedia('(prefers-color-scheme: dark)').matches) || false) "
#          '{\n'
#          "          document.documentElement.classList.add('dark');\n"
#          '        } else {\n'
#          "          document.documentElement.classList.remove('dark');\n"
#          '        }\n'
#          '      } catch (_) {}</script><link rel="preload" '
#          'href="/_next/static/css/108947c928d1031f.css" as="style"><link '
#          'rel="stylesheet" href="/_next/static/css/108947c928d1031f.css" '
#          'data-n-g=""><link rel="preload" '
#          'href="/_next/static/css/8c76fb7d3768dfe7.css" as="style"><noscript '
#          'data-n-css=""></noscript><style '
#          'data-n-href="/_next/static/css/8c76fb7d3768dfe7.css">html.dark '
#          '.namespace,html:not(.dark) .codeblock-dark '
#          '.namespace{opacity:.7}html.dark .token.doctype '
#          '.token.doctype-tag,html:not(.dark) .codeblock-dark .token.doctype '
#          '.token.doctype-tag{color:#569cd6}html.dark .token.doctype '
#          '.token.name,html:not(.dark) .codeblock-dark .token.doctype '
#          '.token.name{color:#9cdcfe}html.dark .token.comment,html.dark '
#          '.token.prolog,html:not(.dark) .codeblock-dark '
#          '.token.comment,html:not(.dark) .codeblock-dark '
#          '.token.prolog{color:#6a9955}html.dark .language-html .language-css '
#          '.token.punctuation,html.dark .language-html .language-javascript '
#          '.token.punctuation,html.dark .token.punctuation,html:not(.dark) '
#          '.codeblock-dark .language-html .language-css '
#          '.token.punctuation,html:not(.dark) .codeblock-dark .language-html '
#          '.language-javascript .token.punctuation,html:not(.dark) '
#          '.codeblock-dark .token.punctuation{color:#d4d4d4}html.dark '
#          '.token.boolean,html.dark .token.constant,html.dark '
#          '.token.inserted,html.dark .token.number,html.dark '
#          '.token.property,html.dark .token.symbol,html.dark '
#          '.token.tag,html.dark .token.unit,html:not(.dark) .codeblock-dark '
#          '.token.boolean,html:not(.dark) .codeblock-dark '
#          '.token.constant,html:not(.dark) .codeblock-dark '
#          '.token.inserted,html:not(.dark) .codeblock-dark '
#          '.token.number,html:not(.dark) .codeblock-dark '
#          '.token.property,html:not(.dark) .codeblock-dark '
#          '.token.symbol,html:not(.dark) .codeblock-dark '
#          '.token.tag,html:not(.dark) .codeblock-dark '
#          '.token.unit{color:#b5cea8}html.dark .token.attr-name,html.dark '
#          '.token.builtin,html.dark .token.char,html.dark '
#          '.token.deleted,html.dark .token.selector,html.dark '
#          '.token.string,html:not(.dark) .codeblock-dark '
#          '.token.attr-name,html:not(.dark) .codeblock-dark '
#          '.token.builtin,html:not(.dark) .codeblock-dark '
#          '.token.char,html:not(.dark) .codeblock-dark '
#          '.token.deleted,html:not(.dark) .codeblock-dark '
#          '.token.selector,html:not(.dark) .codeblock-dark '
#          '.token.string{color:#ce9178}html.dark '
#          '.token.plain-text,html:not(.dark) .codeblock-dark '
#          '.token.plain-text{color:#fafafa}html.dark .language-css '
#          '.token.string.url,html:not(.dark) .codeblock-dark .language-css '
#          '.token.string.url{text-decoration:underline}html.dark '
#          '.token.entity,html.dark .token.operator,html:not(.dark) '
#          '.codeblock-dark .token.entity,html:not(.dark) .codeblock-dark '
#          '.token.operator{color:#d4d4d4}html.dark '
#          '.token.operator.arrow,html:not(.dark) .codeblock-dark '
#          '.token.operator.arrow{color:#569cd6}html.dark '
#          '.token.atrule,html:not(.dark) .codeblock-dark '
#          '.token.atrule{color:#ce9178}html.dark .token.atrule '
#          '.token.rule,html:not(.dark) .codeblock-dark .token.atrule '
#          '.token.rule{color:#c586c0}html.dark .token.atrule '
#          '.token.url,html:not(.dark) .codeblock-dark .token.atrule '
#          '.token.url{color:#9cdcfe}html.dark .token.atrule .token.url '
#          '.token.function,html:not(.dark) .codeblock-dark .token.atrule '
#          '.token.url .token.function{color:#dcdcaa}html.dark .token.atrule '
#          '.token.url .token.punctuation,html:not(.dark) .codeblock-dark '
#          '.token.atrule .token.url .token.punctuation{color:#d4d4d4}html.dark '
#          '.token.keyword,html:not(.dark) .codeblock-dark '
#          '.token.keyword{color:#569cd6}html.dark '
#          '.token.keyword.control-flow,html.dark '
#          '.token.keyword.module,html:not(.dark) .codeblock-dark '
#          '.token.keyword.control-flow,html:not(.dark) .codeblock-dark '
#          '.token.keyword.module{color:#c586c0}html.dark '
#          '.token.function,html.dark .token.function '
#          '.token.maybe-class-name,html:not(.dark) .codeblock-dark '
#          '.token.function,html:not(.dark) .codeblock-dark .token.function '
#          '.token.maybe-class-name{color:#dcdcaa}html.dark '
#          '.token.regex,html:not(.dark) .codeblock-dark '
#          '.token.regex{color:#d16969}html.dark '
#          '.token.important,html:not(.dark) .codeblock-dark '
#          '.token.important{color:#569cd6}html.dark '
#          '.token.italic,html:not(.dark) .codeblock-dark '
#          '.token.italic{font-style:italic}html.dark '
#          '.token.constant,html:not(.dark) .codeblock-dark '
#          '.token.constant{color:#9cdcfe}html.dark .token.class-name,html.dark '
#          '.token.maybe-class-name,html:not(.dark) .codeblock-dark '
#          '.token.class-name,html:not(.dark) .codeblock-dark '
#          '.token.maybe-class-name{color:#4ec9b0}html.dark '
#          '.token.console,html.dark .token.interpolation,html.dark '
#          '.token.parameter,html:not(.dark) .codeblock-dark '
#          '.token.console,html:not(.dark) .codeblock-dark '
#          '.token.interpolation,html:not(.dark) .codeblock-dark '
#          '.token.parameter{color:#9cdcfe}html.dark .token.boolean,html.dark '
#          '.token.punctuation.interpolation-punctuation,html:not(.dark) '
#          '.codeblock-dark .token.boolean,html:not(.dark) .codeblock-dark '
#          '.token.punctuation.interpolation-punctuation{color:#569cd6}html.dark '
#          '.token.exports .token.maybe-class-name,html.dark .token.imports '
#          '.token.maybe-class-name,html.dark .token.property,html.dark '
#          '.token.variable,html:not(.dark) .codeblock-dark .token.exports '
#          '.token.maybe-class-name,html:not(.dark) .codeblock-dark '
#          '.token.imports .token.maybe-class-name,html:not(.dark) '
#          '.codeblock-dark .token.property,html:not(.dark) .codeblock-dark '
#          '.token.variable{color:#9cdcfe}html.dark .token.escape,html.dark '
#          '.token.selector,html:not(.dark) .codeblock-dark '
#          '.token.escape,html:not(.dark) .codeblock-dark '
#          '.token.selector{color:#d7ba7d}html.dark .token.tag,html:not(.dark) '
#          '.codeblock-dark .token.tag{color:#569cd6}html.dark '
#          '.token.cdata,html.dark .token.tag .token.punctuation,html:not(.dark) '
#          '.codeblock-dark .token.cdata,html:not(.dark) .codeblock-dark '
#          '.token.tag .token.punctuation{color:grey}html.dark '
#          '.token.attr-name,html:not(.dark) .codeblock-dark '
#          '.token.attr-name{color:#9cdcfe}html.dark .token.attr-value,html.dark '
#          '.token.attr-value .token.punctuation,html:not(.dark) .codeblock-dark '
#          '.token.attr-value,html:not(.dark) .codeblock-dark .token.attr-value '
#          '.token.punctuation{color:#ce9178}html.dark .token.attr-value '
#          '.token.punctuation.attr-equals,html:not(.dark) .codeblock-dark '
#          '.token.attr-value '
#          '.token.punctuation.attr-equals{color:#d4d4d4}html.dark '
#          '.token.entity,html:not(.dark) .codeblock-dark '
#          '.token.entity{color:#569cd6}html.dark '
#          '.token.namespace,html:not(.dark) .codeblock-dark '
#          '.token.namespace{color:#4ec9b0}html.dark '
#          '.token.operator,html:not(.dark) .codeblock-dark '
#          '.token.operator{--tw-text-opacity:1;color:rgb(148 163 '
#          '184/var(--tw-text-opacity))}html.dark '
#          'code[class*=language-javascript],html.dark '
#          'code[class*=language-jsx],html.dark '
#          'code[class*=language-tsx],html.dark '
#          'code[class*=language-typescript],html.dark '
#          'pre[class*=language-javascript],html.dark '
#          'pre[class*=language-jsx],html.dark '
#          'pre[class*=language-tsx],html.dark '
#          'pre[class*=language-typescript],html:not(.dark) .codeblock-dark '
#          'code[class*=language-javascript],html:not(.dark) .codeblock-dark '
#          'code[class*=language-jsx],html:not(.dark) .codeblock-dark '
#          'code[class*=language-tsx],html:not(.dark) .codeblock-dark '
#          'code[class*=language-typescript],html:not(.dark) .codeblock-dark '
#          'pre[class*=language-javascript],html:not(.dark) .codeblock-dark '
#          'pre[class*=language-jsx],html:not(.dark) .codeblock-dark '
#          'pre[class*=language-tsx],html:not(.dark) .codeblock-dark '
#          'pre[class*=language-typescript]{color:#9cdcfe}html.dark '
#          'code[class*=language-css],html.dark '
#          'pre[class*=language-css],html:not(.dark) .codeblock-dark '
#          'code[class*=language-css],html:not(.dark) .codeblock-dark '
#          'pre[class*=language-css]{color:#ce9178}html.dark '
#          'code[class*=language-html],html.dark '
#          'pre[class*=language-html],html:not(.dark) .codeblock-dark '
#          'code[class*=language-html],html:not(.dark) .codeblock-dark '
#          'pre[class*=language-html]{color:#d4d4d4}html.dark .language-regex '
#          '.token.anchor,html:not(.dark) .codeblock-dark .language-regex '
#          '.token.anchor{color:#dcdcaa}html.dark .language-html '
#          '.token.punctuation,html:not(.dark) .codeblock-dark .language-html '
#          '.token.punctuation{color:grey}html.dark code.language-toml '
#          '.table,html:not(.dark) .codeblock-dark code.language-toml '
#          '.table{display:inherit}html.dark '
#          'pre[class*=language-]>code[class*=language-],html:not(.dark) '
#          '.codeblock-dark '
#          'pre[class*=language-]>code[class*=language-]{position:relative;z-index:1;display:block;width:max-content;min-width:100%}html.dark '
#          '.line-highlight,html:not(.dark) .codeblock-dark '
#          '.line-highlight{background:rgb(var(--primary-light)/.2);width:100%;display:inline-block;position:relative;z-index:0}html.dark '
#          '.line-highlight:after,html.dark '
#          '.line-highlight:before,html:not(.dark) .codeblock-dark '
#          '.line-highlight:after,html:not(.dark) .codeblock-dark '
#          '.line-highlight:before{content:"";position:absolute;top:0;bottom:0;width:1.25rem;background:rgb(var(--primary-light)/.2)}html.dark '
#          '.line-highlight:before,html:not(.dark) .codeblock-dark '
#          '.line-highlight:before{left:-1.25rem;border-left:4px solid '
#          'rgb(var(--primary-light)/1)}html.dark '
#          '.line-highlight:after,html:not(.dark) .codeblock-dark '
#          '.line-highlight:after{right:-1.25rem}html.dark '
#          'pre[class^=language-diff-],html:not(.dark) .codeblock-dark '
#          'pre[class^=language-diff-]{display:flex;padding-left:2.25rem;padding-right:2.25rem}html.dark '
#          'pre[class^=language-diff-]>code,html:not(.dark) .codeblock-dark '
#          'pre[class^=language-diff-]>code{min-width:100%;flex:none}html:not(.dark) '
#          '.codeblock-light .namespace{opacity:.7}html:not(.dark) '
#          '.codeblock-light .token.cdata,html:not(.dark) .codeblock-light '
#          '.token.comment,html:not(.dark) .codeblock-light '
#          '.token.doctype,html:not(.dark) .codeblock-light '
#          '.token.prolog{color:#6e7781}html:not(.dark) .codeblock-light '
#          '.token.punctuation{color:#24292f}html:not(.dark) .codeblock-light '
#          '.token.boolean,html:not(.dark) .codeblock-light '
#          '.token.constant,html:not(.dark) .codeblock-light '
#          '.token.deleted,html:not(.dark) .codeblock-light '
#          '.token.number,html:not(.dark) .codeblock-light '
#          '.token.property,html:not(.dark) .codeblock-light '
#          '.token.symbol,html:not(.dark) .codeblock-light '
#          '.token.tag{color:#0550ae}html:not(.dark) .codeblock-light '
#          '.token.attr-name,html:not(.dark) .codeblock-light '
#          '.token.builtin,html:not(.dark) .codeblock-light '
#          '.token.char,html:not(.dark) .codeblock-light '
#          '.token.inserted,html:not(.dark) .codeblock-light '
#          '.token.selector,html:not(.dark) .codeblock-light '
#          '.token.string{color:#0a3069}html:not(.dark) .codeblock-light '
#          '.language-css .token.string,html:not(.dark) .codeblock-light .style '
#          '.token.string,html:not(.dark) .codeblock-light '
#          '.token.entity,html:not(.dark) .codeblock-light '
#          '.token.operator,html:not(.dark) .codeblock-light '
#          '.token.url{color:#0550ae}html:not(.dark) .codeblock-light '
#          '.token.atrule,html:not(.dark) .codeblock-light '
#          '.token.attr-value,html:not(.dark) .codeblock-light '
#          '.token.keyword{color:#cf222e}html:not(.dark) .codeblock-light '
#          '.token.function{color:#8250df}html:not(.dark) .codeblock-light '
#          '.token.important,html:not(.dark) .codeblock-light '
#          '.token.regex,html:not(.dark) .codeblock-light '
#          '.token.variable{color:#0a3069}html:not(.dark) .codeblock-light '
#          '.token.bold,html:not(.dark) .codeblock-light '
#          '.token.important{font-weight:700}html:not(.dark) .codeblock-light '
#          '.token.italic{font-style:italic}html:not(.dark) .codeblock-light '
#          '.token.entity{cursor:help}html:not(.dark) .codeblock-light '
#          '.language-css .token.selector{color:#116329}html:not(.dark) '
#          '.codeblock-light .language-css '
#          '.token.property{color:#0550ae}html:not(.dark) .codeblock-light '
#          '.language-css .token.atrule .token.rule,html:not(.dark) '
#          '.codeblock-light .language-css .token.important,html:not(.dark) '
#          '.codeblock-light .language-javascript .token.keyword,html:not(.dark) '
#          '.codeblock-light .language-js '
#          '.token.keyword{color:#cf222e}html:not(.dark) .codeblock-light '
#          '.language-javascript .token.atrule,html:not(.dark) .codeblock-light '
#          '.language-javascript .token.boolean,html:not(.dark) .codeblock-light '
#          '.language-javascript .token.constant,html:not(.dark) '
#          '.codeblock-light .language-javascript .token.number,html:not(.dark) '
#          '.codeblock-light .language-javascript '
#          '.token.operator,html:not(.dark) .codeblock-light .language-js '
#          '.token.atrule,html:not(.dark) .codeblock-light .language-js '
#          '.token.boolean,html:not(.dark) .codeblock-light .language-js '
#          '.token.constant,html:not(.dark) .codeblock-light .language-js '
#          '.token.number,html:not(.dark) .codeblock-light .language-js '
#          '.token.operator{color:#0550ae}html:not(.dark) .codeblock-light '
#          '.language-javascript .token.function,html:not(.dark) '
#          '.codeblock-light .language-js '
#          '.token.function{color:#8250df}html:not(.dark) .codeblock-light '
#          '.language-javascript .token.attr-name,html:not(.dark) '
#          '.codeblock-light .language-javascript '
#          '.token.class-name,html:not(.dark) .codeblock-light '
#          '.language-javascript .token.function-variable,html:not(.dark) '
#          '.codeblock-light .language-js .token.attr-name,html:not(.dark) '
#          '.codeblock-light .language-js .token.class-name,html:not(.dark) '
#          '.codeblock-light .language-js '
#          '.token.function-variable{color:var(--color-brown)}html:not(.dark) '
#          '.codeblock-light .language-jsx '
#          '.token.keyword{color:#cf222e}html:not(.dark) .codeblock-light '
#          '.language-jsx .token.function{color:#8250df}html:not(.dark) '
#          '.codeblock-light .language-jsx '
#          '.token.function-variable{color:var(--color-brown)}html:not(.dark) '
#          '.codeblock-light .language-jsx '
#          '.token.punctuation{color:#0550ae}html:not(.dark) .codeblock-light '
#          '.language-jsx .token.attr-name,html:not(.dark) .codeblock-light '
#          '.language-jsx .token.class-name{color:#116329}html:not(.dark) '
#          '.codeblock-light .language-jsx '
#          '.token.string{color:#0a3069}html:not(.dark) .codeblock-light '
#          '.language-json .token.operator{color:#24292f}html:not(.dark) '
#          '.codeblock-light .language-json '
#          '.token.null.keyword{color:#0550ae}html:not(.dark) .codeblock-light '
#          'code.language-toml .table{display:inherit}html:not(.dark) '
#          '.codeblock-light '
#          'pre[class*=language-]>code[class*=language-]{position:relative;z-index:1;display:block;width:max-content;min-width:100%}html:not(.dark) '
#          '.codeblock-light '
#          '.line-highlight{background:rgb(var(--primary-light)/.2);width:100%;display:inline-block;position:relative;z-index:0}html:not(.dark) '
#          '.codeblock-light .line-highlight:after,html:not(.dark) '
#          '.codeblock-light '
#          '.line-highlight:before{content:"";position:absolute;top:0;bottom:0;width:1.25rem;background:rgb(var(--primary-light)/.2)}html:not(.dark) '
#          '.codeblock-light '
#          '.line-highlight:before{left:-1.25rem;border-left:4px solid '
#          'rgb(var(--primary-light)/1)}html:not(.dark) .codeblock-light '
#          '.line-highlight:after{right:-1.25rem}html:not(.dark) '
#          '.codeblock-light '
#          'pre[class^=language-diff-]{display:flex;padding-left:2.25rem;padding-right:2.25rem}html:not(.dark) '
#          '.codeblock-light '
#          'pre[class^=language-diff-]>code{min-width:100%;flex:none}</style><script '
#          'defer="" nomodule="" '
#          'src="/_next/static/chunks/polyfills-42372ed130431b0a.js"></script><script '
#          'src="/_next/static/chunks/webpack-5d6b00e1d1ef43bf.js" '
#          'defer=""></script><script '
#          'src="/_next/static/chunks/framework-9ae01a5f4ade81f5.js" '
#          'defer=""></script><script '
#          'src="/_next/static/chunks/main-cf327937a0d9f14c.js" '
#          'defer=""></script><script '
#          'src="/_next/static/chunks/pages/_app-7ec2088068eb13fe.js" '
#          'defer=""></script><script '
#          'src="/_next/static/chunks/2edb282b-a83f7ffd007bccf0.js" '
#          'defer=""></script><script '
#          'src="/_next/static/chunks/e893f787-f6a1094a35763a0d.js" '
#          'defer=""></script><script '
#          'src="/_next/static/chunks/086d643d-6f7196a364073d16.js" '
#          'defer=""></script><script '
#          'src="/_next/static/chunks/9097-53b32b020063004a.js" '
#          'defer=""></script><script '
#          'src="/_next/static/chunks/4497-2b260bbe03f921f0.js" '
#          'defer=""></script><script '
#          'src="/_next/static/chunks/1301-173d3ce1037cd5c5.js" '
#          'defer=""></script><script '
#          'src="/_next/static/chunks/6953-9909b438e30f91f4.js" '
#          'defer=""></script><script '
#          'src="/_next/static/chunks/8650-32afe3e6efe98702.js" '
#          'defer=""></script><script '
#          'src="/_next/static/chunks/pages/_sites/%5Bsubdomain%5D/%5B%5B...slug%5D%5D-0d7b844ddca37e5d.js" '
#          'defer=""></script><script '
#          'src="/_next/static/SaekEVMMpTvaLnAeDd64H/_buildManifest.js" '
#          'defer=""></script><script '
#          'src="/_next/static/SaekEVMMpTvaLnAeDd64H/_ssgManifest.js" '
#          'defer=""></script><style '
#          'id="__jsx-4145347147">:root{--font-inter:\'__Inter_e5ab12\', '
#          "'__Inter_Fallback_e5ab12';--font-jetbrains-mono:'__JetBrains_Mono_3c557b', "
#          "'__JetBrains_Mono_Fallback_3c557b'}</style><script "
#          'src="https://cdn.lr-in-prod.com/logger-1.min.js" '
#          'async=""></script></head><body><div id="__next"><main '
#          'class="jsx-4145347147"><style>:root {\n'
#          '    --primary: 253 187 17;\n'
#          '    --primary-light: 253 187 17;\n'
#          '    --primary-dark: 70 139 255;\n'
#          '    --background-light: 255 255 255;\n'
#          '    --background-dark: 14 13 11;\n'
#          '    --gray-50: 250 248 243;\n'
#          '    --gray-100: 245 243 238;\n'
#          '    --gray-200: 230 228 223;\n'
#          '    --gray-300: 213 211 206;\n'
#          '    --gray-400: 166 164 159;\n'
#          '    --gray-500: 119 117 112;\n'
#          '    --gray-600: 87 85 80;\n'
#          '    --gray-700: 70 68 63;\n'
#          '    --gray-800: 45 43 37;\n'
#          '    --gray-900: 30 28 23;\n'
#          '    --gray-950: 17 15 10;\n'
#          '  }</style><span class="fixed inset-0 bg-background-light '
#          'dark:bg-background-dark -z-10"></span><div class="relative '
#          'antialiased text-gray-500 dark:text-gray-400"><div id="navbar" '
#          'class="z-30 fixed lg:sticky top-0 w-full"><div '
#          'id="navbar-transition" class="absolute w-full h-full backdrop-blur '
#          'flex-none transition-colors duration-500 border-b border-gray-500/5 '
#          'dark:border-gray-300/[0.06] '
#          'supports-backdrop-blur:bg-background-light/60 '
#          'dark:bg-transparent"></div><div class="max-w-8xl mx-auto '
#          'relative"><div class=""><div class="relative"><div class="flex '
#          'items-center lg:px-12 h-16 min-w-0 mx-4 lg:mx-0"><div class="h-full '
#          'relative flex-1 flex items-center gap-x-4 min-w-0 border-b '
#          'border-gray-500/5 dark:border-gray-300/[0.06]"><div class="flex-1 '
#          'flex items-center gap-x-4"><a href="https://tavily.com/"><span '
#          'class="sr-only">Tavily Docs<!-- --> home page</span><img '
#          'class="w-auto h-7 relative object-contain block dark:hidden" '
#          'src="https://mintlify.s3.us-west-1.amazonaws.com/tavilyai/logo/light.svg" '
#          'alt="light logo"><img class="w-auto h-7 relative object-contain '
#          'hidden dark:block" '
#          'src="https://mintlify.s3.us-west-1.amazonaws.com/tavilyai/logo/dark.svg" '
#          'alt="dark logo"></a><div class="flex items-center '
#          'gap-x-2"></div></div><button type="button" class="hidden lg:flex '
#          'relative flex-1 pointer-events-auto rounded-xl w-full items-center '
#          'text-sm leading-6 py-1.5 pl-3.5 pr-3 shadow-sm text-gray-400 '
#          'dark:text-white/50 bg-background-light dark:bg-background-dark '
#          'dark:brightness-[1.1] dark:ring-1 dark:hover:brightness-[1.25] '
#          'ring-1 ring-gray-400/20 hover:ring-gray-600/25 dark:ring-gray-600/30 '
#          'dark:hover:ring-gray-500/30 focus:outline-primary justify-between '
#          'truncate gap-2 min-w-[43px]" id="search-bar-entry"><div class="flex '
#          'items-center gap-3 min-w-[42px]"><svg '
#          'xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 '
#          '0 24 24" fill="none" stroke="currentColor" stroke-width="2" '
#          'stroke-linecap="round" stroke-linejoin="round" class="lucide '
#          'lucide-search min-w-4 flex-none text-gray-700 hover:text-gray-800 '
#          'dark:text-gray-300 hover:dark:text-gray-200"><circle cx="11" cy="11" '
#          'r="8"></circle><path d="m21 21-4.3-4.3"></path></svg><div '
#          'class="truncate min-w-0">Search or ask...</div></div><span '
#          'class="flex-none text-xs font-semibold">Ctrl K</span></button><div '
#          'class="flex-1 relative hidden lg:flex items-center ml-auto '
#          'justify-end space-x-4"><nav class="text-sm"><ul class="flex '
#          'space-x-6 items-center"><li><a href="mailto:support@tavily.com" '
#          'class="whitespace-nowrap font-medium text-gray-600 '
#          'hover:text-gray-900 dark:text-gray-400 dark:hover:text-gray-300" '
#          'target="_blank">Support</a></li><li class="block lg:hidden"><a '
#          'class="whitespace-nowrap font-medium text-gray-600 '
#          'hover:text-gray-900 dark:text-gray-400 dark:hover:text-gray-300" '
#          'href="https://app.tavily.com">Get an API key</a></li><li '
#          'class="whitespace-nowrap hidden lg:flex" id="topbar-cta-button"><a '
#          'target="_blank" class="group px-4 py-1.5 relative inline-flex '
#          'items-center text-sm font-medium" '
#          'href="https://app.tavily.com"><span class="absolute inset-0 '
#          'bg-primary-dark rounded-full group-hover:opacity-[0.9]"></span><div '
#          'class="mr-0.5 space-x-2.5 flex items-center"><span class="z-10 '
#          'text-white">Get an API key</span><svg width="3" height="24" '
#          'viewBox="0 -9 3 24" class="h-5 rotate-0 overflow-visible '
#          'text-white/90"><path d="M0 0L3 3L0 6" fill="none" '
#          'stroke="currentColor" stroke-width="1.5" '
#          'stroke-linecap="round"></path></svg></div></a></li></ul></nav><div '
#          'class="flex items-center"><button class="group p-2 flex items-center '
#          'justify-center" aria-label="Toggle dark mode"><svg width="16" '
#          'height="16" viewBox="0 0 16 16" fill="none" stroke="currentColor" '
#          'xmlns="http://www.w3.org/2000/svg" class="h-4 w-4 block '
#          'text-gray-400 dark:hidden group-hover:text-gray-600"><g '
#          'clip-path="url(#clip0_2880_7340)"><path d="M8 1.11133V2.00022" '
#          'stroke-width="1.5" stroke-linecap="round" '
#          'stroke-linejoin="round"></path><path d="M12.8711 3.12891L12.2427 '
#          '3.75735" stroke-width="1.5" stroke-linecap="round" '
#          'stroke-linejoin="round"></path><path d="M14.8889 8H14" '
#          'stroke-width="1.5" stroke-linecap="round" '
#          'stroke-linejoin="round"></path><path d="M12.8711 12.8711L12.2427 '
#          '12.2427" stroke-width="1.5" stroke-linecap="round" '
#          'stroke-linejoin="round"></path><path d="M8 14.8889V14" '
#          'stroke-width="1.5" stroke-linecap="round" '
#          'stroke-linejoin="round"></path><path d="M3.12891 12.8711L3.75735 '
#          '12.2427" stroke-width="1.5" stroke-linecap="round" '
#          'stroke-linejoin="round"></path><path d="M1.11133 8H2.00022" '
#          'stroke-width="1.5" stroke-linecap="round" '
#          'stroke-linejoin="round"></path><path d="M3.12891 3.12891L3.75735 '
#          '3.75735" stroke-width="1.5" stroke-linecap="round" '
#          'stroke-linejoin="round"></path><path d="M8.00043 11.7782C10.0868 '
#          '11.7782 11.7782 10.0868 11.7782 8.00043C11.7782 5.91402 10.0868 '
#          '4.22266 8.00043 4.22266C5.91402 4.22266 4.22266 5.91402 4.22266 '
#          '8.00043C4.22266 10.0868 5.91402 11.7782 8.00043 11.7782Z" '
#          'stroke-width="1.5" stroke-linecap="round" '
#          'stroke-linejoin="round"></path></g><defs><clipPath '
#          'id="clip0_2880_7340"><rect width="16" height="16" '
#          'fill="white"></rect></clipPath></defs></svg><svg '
#          'xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 '
#          '0 24 24" fill="none" stroke="currentColor" stroke-width="2" '
#          'stroke-linecap="round" stroke-linejoin="round" class="lucide '
#          'lucide-moon h-4 w-4 hidden dark:block text-gray-500 '
#          'dark:group-hover:text-gray-300"><path d="M12 3a6 6 0 0 0 9 9 9 9 0 1 '
#          '1-9-9Z"></path></svg></button></div></div><div class="flex lg:hidden '
#          'items-center gap-2"><button type="button" class="text-gray-500 w-8 '
#          'h-8 flex items-center justify-center hover:text-gray-600 '
#          'dark:text-gray-400 dark:hover:text-gray-300" '
#          'id="search-bar-entry-mobile"><span '
#          'class="sr-only">Search...</span><svg class="h-4 w-4 bg-gray-500 '
#          'dark:bg-gray-400 hover:bg-gray-600 dark:hover:bg-gray-300" '
#          'style="-webkit-mask-image:url(https://mintlify.b-cdn.net/v6.6.0/solid/magnifying-glass.svg);-webkit-mask-repeat:no-repeat;-webkit-mask-position:center;mask-image:url(https://mintlify.b-cdn.net/v6.6.0/solid/magnifying-glass.svg);mask-repeat:no-repeat;mask-position:center"></svg></button><button '
#          'aria-label="More actions" class="h-7 w-5 flex items-center '
#          'justify-end"><svg class="h-4 w-4 bg-gray-500 dark:bg-gray-400 '
#          'hover:bg-gray-600 dark:hover:bg-gray-300" '
#          'style="-webkit-mask-image:url(https://mintlify.b-cdn.net/v6.6.0/solid/ellipsis-vertical.svg);-webkit-mask-repeat:no-repeat;-webkit-mask-position:center;mask-image:url(https://mintlify.b-cdn.net/v6.6.0/solid/ellipsis-vertical.svg);mask-repeat:no-repeat;mask-position:center"></svg></button></div></div></div><div '
#          'class="flex items-center h-14 py-4 px-5 lg:hidden"><button '
#          'type="button" class="text-gray-500 hover:text-gray-600 '
#          'dark:text-gray-400 dark:hover:text-gray-300"><span '
#          'class="sr-only">Navigation</span><svg class="h-4" '
#          'fill="currentColor" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 '
#          '448 512"><path d="M0 96C0 78.3 14.3 64 32 64H416c17.7 0 32 14.3 32 '
#          '32s-14.3 32-32 32H32C14.3 128 0 113.7 0 96zM0 256c0-17.7 14.3-32 '
#          '32-32H416c17.7 0 32 14.3 32 32s-14.3 32-32 32H32c-17.7 '
#          '0-32-14.3-32-32zM448 416c0 17.7-14.3 32-32 32H32c-17.7 '
#          '0-32-14.3-32-32s14.3-32 32-32H416c17.7 0 32 14.3 32 '
#          '32z"></path></svg></button><div class="ml-4 flex text-sm leading-6 '
#          'whitespace-nowrap min-w-0 space-x-3"><div class="flex items-center '
#          'space-x-3"><span>Python</span><svg width="3" height="24" viewBox="0 '
#          '-9 3 24" class="h-5 rotate-0 overflow-visible fill-gray-400"><path '
#          'd="M0 0L3 3L0 6" fill="none" stroke="currentColor" '
#          'stroke-width="1.5" stroke-linecap="round"></path></svg></div><div '
#          'class="font-semibold text-gray-900 truncate '
#          'dark:text-gray-200">Quickstart</div></div></div></div><div '
#          'class="hidden lg:flex px-12 h-12"><div class="h-full flex text-sm '
#          'space-x-6"><a class="group relative h-full flex items-center '
#          'font-medium text-gray-600 dark:text-gray-400 hover:text-gray-800 '
#          'dark:hover:text-gray-300" href="/welcome">Home<div class="absolute '
#          'bottom-0 h-[1.5px] w-full group-hover:bg-gray-200 '
#          'dark:group-hover:bg-gray-700"></div></a><a class="group relative '
#          'h-full flex items-center font-medium text-gray-600 '
#          'dark:text-gray-400 hover:text-gray-800 dark:hover:text-gray-300" '
#          'href="/documentation/about">Documentation<div class="absolute '
#          'bottom-0 h-[1.5px] w-full group-hover:bg-gray-200 '
#          'dark:group-hover:bg-gray-700"></div></a><a class="group relative '
#          'h-full flex items-center text-gray-800 dark:text-gray-200 '
#          'font-semibold" href="/sdk/python/quick-start">SDKs<div '
#          'class="absolute bottom-0 h-[1.5px] w-full bg-primary '
#          'dark:bg-primary-light"></div></a><a class="group relative h-full '
#          'flex items-center font-medium text-gray-600 dark:text-gray-400 '
#          'hover:text-gray-800 dark:hover:text-gray-300" '
#          'href="/examples/use-cases/data-enrichment">Examples<div '
#          'class="absolute bottom-0 h-[1.5px] w-full group-hover:bg-gray-200 '
#          'dark:group-hover:bg-gray-700"></div></a></div></div></div></div></div><div '
#          'class="max-w-8xl px-4 mx-auto lg:px-8"><div class="z-20 hidden '
#          'lg:block fixed bottom-0 right-auto w-[18rem]" id="sidebar" '
#          'style="top:7rem"><div class="absolute inset-0 z-10 '
#          'stable-scrollbar-gutter overflow-auto pr-8 pb-10" '
#          'id="sidebar-content"><div class="relative lg:text-sm '
#          'lg:leading-6"><div class="sticky top-0 h-8 bg-gradient-to-b '
#          'from-background-light dark:from-background-dark"></div><div '
#          'id="navigation-items"><li class="list-none"><a '
#          'href="https://app.tavily.com/playground" target="_blank" '
#          'rel="noreferrer" class="pl-4 group flex items-center lg:text-sm '
#          'lg:leading-6 mb-5 sm:mb-4 font-medium text-gray-600 '
#          'hover:text-gray-900 dark:text-gray-400 '
#          'dark:hover:text-gray-300"><div class="mr-4 rounded-md p-1 zinc-box '
#          'group-hover:brightness-100 group-hover:ring-0 ring-1 ring-gray-950/5 '
#          'dark:ring-gray-700/40"><svg class="h-4 w-4 secondary-opacity '
#          'group-hover:fill-primary-dark group-hover:bg-white bg-gray-400 '
#          'dark:bg-gray-500" '
#          'style="-webkit-mask-image:url(https://mintlify.b-cdn.net/v6.6.0/duotone/play.svg);-webkit-mask-repeat:no-repeat;-webkit-mask-position:center;mask-image:url(https://mintlify.b-cdn.net/v6.6.0/duotone/play.svg);mask-repeat:no-repeat;mask-position:center"></svg></div>API '
#          'Playground</a></li><li class="list-none"><a '
#          'href="https://community.tavily.com" target="_blank" rel="noreferrer" '
#          'class="pl-4 group flex items-center lg:text-sm lg:leading-6 mb-5 '
#          'sm:mb-4 font-medium text-gray-600 hover:text-gray-900 '
#          'dark:text-gray-400 dark:hover:text-gray-300"><div class="mr-4 '
#          'rounded-md p-1 zinc-box group-hover:brightness-100 '
#          'group-hover:ring-0 ring-1 ring-gray-950/5 '
#          'dark:ring-gray-700/40"><svg class="h-4 w-4 secondary-opacity '
#          'group-hover:fill-primary-dark group-hover:bg-white bg-gray-400 '
#          'dark:bg-gray-500" '
#          'style="-webkit-mask-image:url(https://mintlify.b-cdn.net/v6.6.0/duotone/user-group.svg);-webkit-mask-repeat:no-repeat;-webkit-mask-position:center;mask-image:url(https://mintlify.b-cdn.net/v6.6.0/duotone/user-group.svg);mask-repeat:no-repeat;mask-position:center"></svg></div>Community</a></li><li '
#          'class="list-none"><a href="https://blog.tavily.com" target="_blank" '
#          'rel="noreferrer" class="pl-4 group flex items-center lg:text-sm '
#          'lg:leading-6 mb-5 sm:mb-4 font-medium text-gray-600 '
#          'hover:text-gray-900 dark:text-gray-400 '
#          'dark:hover:text-gray-300"><div class="mr-4 rounded-md p-1 zinc-box '
#          'group-hover:brightness-100 group-hover:ring-0 ring-1 ring-gray-950/5 '
#          'dark:ring-gray-700/40"><svg class="h-4 w-4 secondary-opacity '
#          'group-hover:fill-primary-dark group-hover:bg-white bg-gray-400 '
#          'dark:bg-gray-500" '
# ...
#          '\\"response\\", _jsx(_components.span, {\\n              className: '
#          '\\"token punctuation\\",\\n              children: '
#          '\\")\\"\\n            })]\\n          }), \\"\\\\n\\"]\\n        '
#          '})\\n      })\\n    }), \\"\\\\n\\", _jsx(_components.p, {\\n      '
#          'children: \\"These examples are very simple, and you can do so much '
#          'more with Tavily!\\"\\n    }), \\"\\\\n\\", _jsx(Heading, {\\n      '
#          'level: \\"2\\",\\n      id: \\"features\\",\\n      children: '
#          '\\"Features\\"\\n    }), \\"\\\\n\\", _jsxs(_components.p, {\\n      '
#          'children: [\\"Our Python SDK supports the full feature range of our '
#          '\\", _jsx(_components.a, {\\n        href: '
#          '\\"/api-reference\\",\\n        children: \\"REST API\\"\\n      }), '
#          '\\", and more. We offer both a synchronous and an asynchronous '
#          'client, for increased flexibility.\\"]\\n    }), \\"\\\\n\\", '
#          '_jsxs(_components.ul, {\\n      children: [\\"\\\\n\\", '
#          '_jsxs(_components.li, {\\n        children: [\\"The \\", '
#          '_jsx(_components.code, {\\n          children: '
#          '\\"search\\"\\n        }), \\" function lets you harness the full '
#          'power of Tavily Search.\\"]\\n      }), \\"\\\\n\\", '
#          '_jsxs(_components.li, {\\n        children: [\\"The \\", '
#          '_jsx(_components.code, {\\n          children: '
#          '\\"extract\\"\\n        }), \\" function allows you to easily '
#          'retrieve web content with Tavily Extract.\\"]\\n      }), '
#          '\\"\\\\n\\"]\\n    }), \\"\\\\n\\", _jsxs(_components.p, {\\n      '
#          'children: [\\"For more details, head to the \\", _jsx(_components.a, '
#          '{\\n        href: \\"/sdk/python/reference\\",\\n        children: '
#          '\\"Python SDK Reference\\"\\n      }), \\".\\"]\\n    })]\\n  '
#          '});\\n}\\nfunction MDXContent(props = {}) {\\n  const {wrapper: '
#          'MDXLayout} = {\\n    ..._provideComponents(),\\n    '
#          '...props.components\\n  };\\n  return MDXLayout ? _jsx(MDXLayout, '
#          '{\\n    ...props,\\n    children: _jsx(_createMdxContent, {\\n      '
#          '...props\\n    })\\n  }) : _createMdxContent(props);\\n}\\nreturn '
#          '{\\n  default: MDXContent\\n};\\nfunction _missingMdxReference(id, '
#          'component) {\\n  throw new Error(\\"Expected \\" + (component ? '
#          '\\"component\\" : \\"object\\") + \\" `\\" + id + \\"` to be '
#          'defined: you likely forgot to import, pass, or provide '
#          'it.\\");\\n}\\n","frontmatter":{},"scope":{"config":{"$schema":"https://mintlify.com/docs.json","theme":"mint","name":"Tavily '
#          'Docs","colors":{"primary":"#FDBB11","light":"#FDBB11","dark":"#468BFF"},"favicon":"/favicon.svg","navigation":{"tabs":[{"tab":"Home","groups":[{"group":"Welcome","pages":["welcome"]}]},{"tab":"Documentation","groups":[{"group":"Overview","pages":["documentation/about","documentation/quickstart","documentation/api-credits","documentation/rate-limits"]},{"group":"API '
#          'Reference","pages":["documentation/api-reference/introduction","documentation/api-reference/endpoint/search","documentation/api-reference/endpoint/extract"]},{"group":"Tavily '
#          'MCP '
#          'Server","pages":["documentation/mcp"]},{"group":"Integrations","pages":["documentation/integrations/langchain","documentation/integrations/llamaindex","documentation/integrations/zapier"]},{"group":"Legal","pages":["documentation/trust","documentation/privacy"]}]},{"tab":"SDKs","groups":[{"group":"Python","pages":["sdk/python/quick-start","sdk/python/reference"]},{"group":"JavaScript","pages":["sdk/javascript/quick-start","sdk/javascript/reference"]}]},{"tab":"Examples","groups":[{"group":"Use '
#          'Cases","pages":["examples/use-cases/data-enrichment","examples/use-cases/company-research","examples/use-cases/web-eval"]},{"group":"Open '
#          'Sources","pages":["examples/open-sources/gpt-researcher"]}]}],"global":{"anchors":[{"anchor":"API '
#          'Playground","href":"https://app.tavily.com/playground","icon":"play"},{"anchor":"Community","href":"https://community.tavily.com","icon":"user-group"},{"anchor":"Blog","href":"https://blog.tavily.com","icon":"newspaper"}]}},"logo":{"light":"https://mintlify.s3.us-west-1.amazonaws.com/tavilyai/logo/light.svg","dark":"https://mintlify.s3.us-west-1.amazonaws.com/tavilyai/logo/dark.svg","href":"https://tavily.com/"},"api":{"playground":{"display":"simple"}},"navbar":{"links":[{"label":"Support","href":"mailto:support@tavily.com"}],"primary":{"type":"button","label":"Get '
#          'an API '
#          'key","href":"https://app.tavily.com"}},"footer":{"socials":{"x":"https://x.com/tavilyai","github":"https://github.com/tavily-ai","linkedin":"https://linkedin.com/company/tavily","website":"https://tavily.com"}},"redirects":[{"destination":"/documentation/about","source":"/guides/introduction","_id":"67d8acc8937daff40364db31"},{"destination":"/documentation/quickstart","source":"/guides/quickstart","_id":"67d8acc8937daff40364db32"},{"destination":"/documentation/api-reference/introduction","source":"/api-reference/introduction","_id":"67d8acc8937daff40364db33"},{"destination":"/documentation/api-reference/endpoint/search","source":"/api-reference/endpoint/search","_id":"67d8acc8937daff40364db34"},{"destination":"/documentation/api-reference/endpoint/extract","source":"/api-reference/endpoint/extract","_id":"67d8acc8937daff40364db35"},{"destination":"/sdk/python/quick-start","source":"/sdk/introduction","_id":"67d8acc8937daff40364db36"},{"destination":"/sdk/python/quick-start","source":"/sdk/python/get-started","_id":"67d8acc8937daff40364db37"},{"destination":"/sdk/javascript/quick-start","source":"/sdk/javascript/get-started","_id":"67d8acc8937daff40364db38"},{"destination":"/documentation/integrations/langchain","source":"/integrations/langchain","_id":"67d8acc8937daff40364db39"},{"destination":"/documentation/integrations/llamaindex","source":"/integrations/llamaindex","_id":"67d8acc8937daff40364db3a"},{"destination":"/documentation/integrations/zapier","source":"/integrations/zapier","_id":"67d8acc8937daff40364db3b"},{"destination":"/examples/open-sources/gpt-researcher","source":"/guides/gpt-researcher/gpt-researcher","_id":"67d8acc8937daff40364db3c"},{"destination":"/examples/use-cases/data-enrichment","source":"/guides/use-cases/data-enrichment","_id":"67d8acc8937daff40364db3d"},{"destination":"/examples/use-cases/company-research","source":"/guides/use-cases/company-research","_id":"67d8acc8937daff40364db3e"},{"destination":"/examples/use-cases/web-eval","source":"/guides/use-cases/web-eval","_id":"67d8acc8937daff40364db3f"},{"destination":"/documentation/mcp","source":"/guides/mcp","_id":"67d8acc8937daff40364db40"},{"destination":"/documentation/rate-limits","source":"/guides/rate-limits","_id":"67d8acc8937daff40364db41"},{"destination":"/documentation/api-credits","source":"/guides/api-credits","_id":"67d8acc8937daff40364db42"},{"destination":"/welcome","source":"https://tavily-ai.github.io/","_id":"67d8acc8937daff40364db43"}]},"pageMetadata":{"title":"Quickstart","description":"Integrate '
#          "Tavily's powerful APIs natively in your Python "
#          'apps.","icon":"forward","href":"/sdk/python/quick-start"}}},"entitlements":{"AI_CHAT":{"status":"ENABLED"}},"gitSource":{"type":"github","owner":"tavily-ai","repo":"new-docs","deployBranch":"main","contentDirectory":"","isPrivate":true},"banner":null},"__N_SSG":true},"page":"/_sites/[subdomain]/[[...slug]]","query":{"subdomain":"docs.tavily.com","slug":["sdk","python","quick-start"]},"buildId":"SaekEVMMpTvaLnAeDd64H","isFallback":false,"isExperimentalCompile":false,"gsp":true,"scriptLoader":[]}</script><next-route-announcer><p '
#          'aria-live="assertive" id="__next-route-announcer__" role="alert" '
#          'style="border: 0px; clip: rect(0px, 0px, 0px, 0px); height: 1px; '
#          'margin: -1px; overflow: hidden; padding: 0px; position: absolute; '
#          'top: 0px; width: 1px; white-space: nowrap; overflow-wrap: '
#          'normal;"></p></next-route-announcer></body></html>',
#  'js_execution_result': None,
#  'links': {'external': [{'base_domain': '',
#                          'href': 'mailto:support@tavily.com',
#                          'text': 'Support',
#                          'title': ''},
#                         {'base_domain': 'github.com',
#                          'href': 'https://github.com/tavily-ai/tavily-python',
#                          'text': 'GitHub/tavily-ai/tavily-python',
#                          'title': ''},
#                         {'base_domain': 'pypi.org',
#                          'href': 'https://pypi.org/project/tavily-python',
#                          'text': 'PyPItavily-python',
#                          'title': ''},
#                         {'base_domain': 'x.com',
#                          'href': 'https://x.com/tavilyai',
#                          'text': 'x',
#                          'title': ''},
#                         {'base_domain': 'github.com',
#                          'href': 'https://github.com/tavily-ai',
#                          'text': 'github',
#                          'title': ''},
#                         {'base_domain': 'linkedin.com',
#                          'href': 'https://linkedin.com/company/tavily',
#                          'text': 'linkedin',
#                          'title': ''},
#                         {'base_domain': 'mintlify.com',
#                          'href': 'https://mintlify.com/preview-request?utm_campaign=poweredBy&utm_medium=docs&utm_source=docs.tavily.com',
#                          'text': 'Powered by Mintlify',
#                          'title': ''}],
#            'internal': [{'base_domain': 'tavily.com',
#                          'href': 'https://tavily.com/',
#                          'text': 'Tavily Docs home page',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://app.tavily.com',
#                          'text': 'Get an API key',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://docs.tavily.com/welcome',
#                          'text': 'Home',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://docs.tavily.com/documentation/about',
#                          'text': 'Documentation',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://docs.tavily.com/sdk/python/quick-start',
#                          'text': 'SDKs',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://docs.tavily.com/examples/use-cases/data-enrichment',
#                          'text': 'Examples',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://app.tavily.com/playground',
#                          'text': 'API Playground',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://community.tavily.com',
#                          'text': 'Community',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://blog.tavily.com',
#                          'text': 'Blog',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://docs.tavily.com/sdk/python/reference',
#                          'text': 'SDK Reference',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://docs.tavily.com/sdk/javascript/quick-start',
#                          'text': 'Quickstart',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://docs.tavily.com/sdk/javascript/reference',
#                          'text': 'SDK Reference',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://docs.tavily.com/sdk/python/quick-start#introduction',
#                          'text': '\u200b',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://docs.tavily.com/sdk/python/quick-start#quickstart',
#                          'text': '\u200b',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://docs.tavily.com/sdk/python/quick-start#installation',
#                          'text': '\u200b',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://docs.tavily.com/sdk/python/quick-start#usage',
#                          'text': '\u200b',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://docs.tavily.com/sdk/python/quick-start#features',
#                          'text': '\u200b',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://docs.tavily.com/api-reference',
#                          'text': 'REST API',
#                          'title': ''},
#                         {'base_domain': 'tavily.com',
#                          'href': 'https://tavily.com',
#                          'text': 'website',
#                          'title': ''}]},
#  'media': {'audios': [], 'images': [], 'videos': []},
#  'metadata': {'author': None,
#               'description': "Integrate Tavily's powerful APIs natively in "
#                              'your Python apps.',
#               'keywords': None,
#               'og:image': 'https://tavilyai.mintlify.app/_next/image?url=%2Fapi%2Fog%3Fdivision%3DDocumentation%26title%3DQuickstart%26description%3DIntegrate%2BTavily%2527s%2Bpowerful%2BAPIs%2Bnatively%2Bin%2Byour%2BPython%2Bapps.%26logoLight%3Dhttps%253A%252F%252Fmintlify.s3.us-west-1.amazonaws.com%252Ftavilyai%252Flogo%252Flight.svg%26logoDark%3Dhttps%253A%252F%252Fmintlify.s3.us-west-1.amazonaws.com%252Ftavilyai%252Flogo%252Fdark.svg%26primaryColor%3D%2523FDBB11%26lightColor%3D%2523FDBB11%26darkColor%3D%2523468BFF&w=1200&q=100',
#               'og:image:height': '630',
#               'og:image:width': '1200',
#               'title': 'Quickstart - Tavily Docs',
#               'twitter:card': 'summary_large_image',
#               'twitter:title': 'Quickstart - Tavily Docs'},
#  'pdf': None,
#  'redirected_url': 'https://docs.tavily.com/sdk/python/quick-start',
#  'response_headers': {'age': '33502',
#                       'cache-control': 'public, max-age=0, must-revalidate',
#                       'content-encoding': 'br',
#                       'content-type': 'text/html; charset=utf-8',
#                       'date': 'Tue, 18 Mar 2025 03:57:40 GMT',
#                       'etag': 'W/"sne0cfb0pv234y"',
#                       'server': 'Vercel',
#                       'strict-transport-security': 'max-age=63072000',
#                       'x-frame-options': 'DENY',
#                       'x-matched-path': '/_sites/[subdomain]/[[...slug]]',
#                       'x-powered-by': 'Next.js',
#                       'x-vercel-cache': 'HIT',
#                       'x-vercel-id': 'pdx1::iad1::m2k6f-1742303762734-71a5186e6f28'},
#  'screenshot': None,
#  'session_id': None,
#  'ssl_certificate': None,
#  'status_code': 200,
#  'success': True,
#  'url': 'https://docs.tavily.com/sdk/python/quick-start'}

# %%
#| hide
nbdev.nbdev_export('./crawler.ipynb')
